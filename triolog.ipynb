# %%
from triolog import triolog

# %%
t, data = triolog("test.resp", doplot=True)
print data.shape
# Out:
# (156186,)

# %%
t, data = triolog("test.puls", doplot=True)
print data.shape
# Out:
# (156186,)
